# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from scipy import stats

# %%
df=pd.read_csv('structured_data.csv')
df.head()
# Out:
#    CustomerKey       Customer ID  OrderDateKey      Date  SalesOrderLineKey  \
# 0           -1  [Not Applicable]      20170702  7/2/2017           43659001
# 1           -1  [Not Applicable]      20170702  7/2/2017           43659002
# 2           -1  [Not Applicable]      20170702  7/2/2017           43659003
# 3           -1  [Not Applicable]      20170702  7/2/2017           43659004
# 4           -1  [Not Applicable]      20170702  7/2/2017           43659005
#
#   Sales Order Sales Amount
# 0     SO43659    $2,024.99
# 1     SO43659    $6,074.98
# 2     SO43659    $2,024.99
# 3     SO43659    $2,039.99
# 4     SO43659    $2,039.99

# %%
df['Date'] = pd.to_datetime(df['Date'])
datatypes = df['Date'].dtypes
print(datatypes)
datatypes1 = df['CustomerKey'].dtypes
print(datatypes1)
datatypes2 = df['Customer ID'].dtypes
print(datatypes2)
datatypes3 = df['SalesOrderLineKey'].dtypes
print(datatypes3)
datatypes4 = df['Sales Order'].dtypes
print(datatypes4)
datatypes5 = df['Sales Amount'].dtypes
print(datatypes5)
# Out:
# datetime64[ns]
# int64
# object
# int64
# object
# object

# %%
datatypes = pd.to_datetime(df['Date'])
print(datatypes)
# Out:
# 0        2017-07-02
# 1        2017-07-02
# 2        2017-07-02
# 3        2017-07-02
# 4        2017-07-02
#             ...
# 121248   2019-12-18
# 121249   2019-12-18
# 121250   2018-01-13
# 121251   2019-02-19
# 121252   2019-02-10
# Name: Date, Length: 121253, dtype: datetime64[ns]

# %%
df['Sales Amount'] = df['Sales Amount'].replace({'\$': '', ',': ''}, regex=True).astype(float)
df.head()
# Out:
#    CustomerKey       Customer ID  OrderDateKey       Date  SalesOrderLineKey  \
# 0           -1  [Not Applicable]      20170702 2017-07-02           43659001
# 1           -1  [Not Applicable]      20170702 2017-07-02           43659002
# 2           -1  [Not Applicable]      20170702 2017-07-02           43659003
# 3           -1  [Not Applicable]      20170702 2017-07-02           43659004
# 4           -1  [Not Applicable]      20170702 2017-07-02           43659005
#
#   Sales Order  Sales Amount
# 0     SO43659       2024.99
# 1     SO43659       6074.98
# 2     SO43659       2024.99
# 3     SO43659       2039.99
# 4     SO43659       2039.99

# %%
most_recent = df['Date'].max()
print(most_recent)
pivot_df = df.groupby('CustomerKey')['Date'].max()
print(pivot_df)
df['MaxDate'] = df['CustomerKey'].map(pivot_df)
df.head()
# Out:
# 2020-06-15 00:00:00
# CustomerKey
# -1       2020-06-15
#  11000   2019-10-04
#  11001   2020-05-12
#  11002   2019-07-27
#  11003   2019-10-11
#             ...
#  29479   2019-02-05
#  29480   2019-12-18
#  29481   2018-01-13
#  29482   2019-02-19
#  29483   2019-02-10
# Name: Date, Length: 18485, dtype: datetime64[ns]
#    CustomerKey       Customer ID  OrderDateKey       Date  SalesOrderLineKey  \
# 0           -1  [Not Applicable]      20170702 2017-07-02           43659001
# 1           -1  [Not Applicable]      20170702 2017-07-02           43659002
# 2           -1  [Not Applicable]      20170702 2017-07-02           43659003
# 3           -1  [Not Applicable]      20170702 2017-07-02           43659004
# 4           -1  [Not Applicable]      20170702 2017-07-02           43659005
#
#   Sales Order  Sales Amount    MaxDate
# 0     SO43659       2024.99 2020-06-15
# 1     SO43659       6074.98 2020-06-15
# 2     SO43659       2024.99 2020-06-15
# 3     SO43659       2039.99 2020-06-15
# 4     SO43659       2039.99 2020-06-15

# %% [markdown]
# **Calculate Recency**
#
# Recency of each CustomerKey is calculated by subtracting 'MaxDate' from 'most_recent'.

# %%
Recency = df.groupby(['CustomerKey']).agg({'Date': lambda x: ((most_recent-x.max()).days)})
Recency.head(10)
# Out:
#              Date
# CustomerKey
# -1              0
#  11000        255
#  11001         34
#  11002        324
#  11003        248
#  11004        257
#  11005        256
#  11006        244
#  11007        300
#  11008        317

# %%
dfR = pd.DataFrame(Recency)
dfR['Recency_Score'] = pd.qcut(dfR['Date'], q=4, labels=[1, 2, 3, 4])
dfR.head(10)
# Out:
#              Date Recency_Score
# CustomerKey
# -1              0             1
#  11000        255             4
#  11001         34             1
#  11002        324             4
#  11003        248             3
#  11004        257             4
#  11005        256             4
#  11006        244             3
#  11007        300             4
#  11008        317             4

# %%
mean = dfR['Date'].mean()
median = dfR['Date'].median()
min_date = dfR['Date'].min()
max_date = dfR['Date'].max()
Q1 = dfR['Date'].quantile(0.25)
Q2 = dfR['Date'].quantile(0.5)
Q3 = dfR['Date'].quantile(0.75)
IQR = Q3 - Q1
lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR
print(mean, median, min_date, max_date, Q1, Q2, Q3, IQR, lower_limit, upper_limit)
# Out:
# 174.65853394644307 153.0 0 1080 71.0 153.0 248.0 177.0 -194.5 513.5

# %%
Q1 = dfR['Date'].quantile(0.25)
Q3 = dfR['Date'].quantile(0.75)
IQR = Q3 - Q1
outliers = dfR[(dfR['Date'] < (Q1 - 1.5 * IQR)) | (dfR['Date'] > (Q3 + 1.5 * IQR))]
print(outliers)
# Out:
#              Date Recency_Score
# CustomerKey
# 19802        1065             4
# 20075         773             4
# 22971         919             4
# 22975         922             4
# 23566         832             4
# ...           ...           ...
# 29467         954             4
# 29474         939             4
# 29475         929             4
# 29476         907             4
# 29481         884             4
#
# [394 rows x 2 columns]

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
dfR[["Date"]].hist(bins=50, ax=axes[0])
sns.boxplot(x=dfR['Date'])
# Out:
# <Axes: xlabel='Date'>

# %%
from typing import Tuple
from sklearn.base import BaseEstimator, TransformerMixin


def find_boxplot_boundaries(
    col: pd.Series, whisker_coeff: float = 1.5
) -> Tuple[float, float]:
    """Findx minimum and maximum in boxplot.

    Args:
        col: a pandas serires of input.
        whisker_coeff: whisker coefficient in box plot
    """
    Q1 = col.quantile(0.25)
    Q3 = col.quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - whisker_coeff * IQR
    upper = Q3 + whisker_coeff * IQR
    return lower, upper


class BoxplotOutlierClipper(BaseEstimator, TransformerMixin):
    def __init__(self, whisker_coeff: float = 1.5):
        self.whisker = whisker_coeff
        self.lower = None
        self.upper = None

    def fit(self, X: pd.Series):
        self.lower, self.upper = find_boxplot_boundaries(X, self.whisker)
        return self

    def transform(self, X):
        return X.clip(self.lower, self.upper)

# %%
clipped_total_rooms = BoxplotOutlierClipper().fit_transform(dfR["Date"])

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
clipped_total_rooms.hist(bins=50, ax=axes[0])
clipped_total_rooms.to_frame().boxplot(ax=axes[1], vert=False);

# %%
# transform training data & save lambda value
# Add a constant to make all data positive
dfR['Date'] = dfR['Date'] + abs(dfR['Date'].min()) + 1
fitted_data, fitted_lambda = stats.boxcox(dfR['Date'])
 
# creating axes to draw plots
fig, ax = plt.subplots(1, 2)
 
# plotting the original data(non-normal) and 
# fitted data (normal)
sns.distplot(dfR['Date'], hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2}, 
            label = "Non-Normal", color ="green", ax = ax[0])
 
sns.distplot(fitted_data, hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2}, 
            label = "Normal", color ="green", ax = ax[1])
 
# adding legends to the subplots
plt.legend(loc = "upper right")

#add title to each histogram
ax[0].set_title('Original Data')
ax[1].set_title('Box-Cox Transformed Data') 
 
# rescaling the subplots
fig.set_figheight(5)
fig.set_figwidth(10)
 
print(f"Lambda value used for Transformation: {fitted_lambda}")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15972\390619076.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfR['Date'], hist = False, kde = True,
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15972\390619076.py:15: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(fitted_data, hist = False, kde = True,
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# Lambda value used for Transformation: 0.36312404799786985

# %%
#create log-transformed data
Date_log = np.log(dfR['Date'])

#define grid of plots
fig, axs = plt.subplots(nrows=1, ncols=2)

# plotting the original data(non-normal) and 
# fitted data (normal)
sns.distplot(dfR['Date'], hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2}, 
            label = "Non-Normal", color ="green", ax = axs[0])
 
sns.distplot(Date_log, hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2}, 
            label = "Normal", color ="green", ax = axs[1])
 
# adding legends to the subplots
plt.legend(loc = "upper right")

#add title to each histogram
axs[0].set_title('Original Data')
axs[1].set_title('Log-Transformed Data')
# rescaling the subplots
fig.set_figheight(5)
fig.set_figwidth(10)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15972\2405812207.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfR['Date'], hist = False, kde = True,
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15972\2405812207.py:13: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Date_log, hist = False, kde = True,
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)

# %%
# Create square root-transformed data
Date_sqrt = np.sqrt(dfR['Date'])

# Define grid of plots
fig, axs = plt.subplots(nrows=1, ncols=2)

# Plotting the original data(non-normal) and fitted data (normal)
sns.distplot(dfR['Date'], hist = False, kde = True,
             kde_kws = {'shade': True, 'linewidth': 2}, 
             label = "Non-Normal", color ="green", ax = axs[0])
 
sns.distplot(Date_sqrt, hist = False, kde = True,
             kde_kws = {'shade': True, 'linewidth': 2}, 
             label = "Normal", color ="green", ax = axs[1])
 
# Adding legends to the subplots
plt.legend(loc = "upper right")

# Add title to each histogram
axs[0].set_title('Original Data')
axs[1].set_title('Square Root-Transformed Data')
# rescaling the subplots
fig.set_figheight(5)
fig.set_figwidth(10)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15972\3574111148.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfR['Date'], hist = False, kde = True,
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15972\3574111148.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Date_sqrt, hist = False, kde = True,
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)

# %%
# Create cube root-transformed data
Date_cbrt = np.cbrt(dfR['Date'])

# Define grid of plots
fig, axs = plt.subplots(nrows=1, ncols=2)

# Plotting the original data(non-normal) and fitted data (normal)
sns.distplot(dfR['Date'], hist = False, kde = True,
             kde_kws = {'shade': True, 'linewidth': 2}, 
             label = "Non-Normal", color ="green", ax = axs[0])
 
sns.distplot(Date_cbrt, hist = False, kde = True,
             kde_kws = {'shade': True, 'linewidth': 2}, 
             label = "Normal", color ="green", ax = axs[1])
 
# Adding legends to the subplots
plt.legend(loc = "upper right")

# Add title to each histogram
axs[0].set_title('Original Data')
axs[1].set_title('Cube Root-Transformed Data')
# rescaling the subplots
fig.set_figheight(5)
fig.set_figwidth(10)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15972\67987116.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfR['Date'], hist = False, kde = True,
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15972\67987116.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Date_cbrt, hist = False, kde = True,
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)

# %% [markdown]
# **Calculate Frequency**
#
# Frequency of each CustomerKey is calculated by counting unique value of 'Sales Order'.

# %%
Frequency = df.drop_duplicates(subset=['Sales Order']).groupby(['CustomerKey'])[['Sales Order']].count()
Frequency.head(23)
# Out:
#              Sales Order
# CustomerKey
# -1                  3796
#  11000                 3
#  11001                 3
#  11002                 3
#  11003                 3
#  11004                 3
#  11005                 3
#  11006                 3
#  11007                 3
#  11008                 3
#  11009                 3
#  11010                 3
#  11011                 3
#  11012                 2
#  11013                 2
#  11014                 2
#  11015                 1
#  11016                 1
#  11017                 3
#  11018                 3
#  11019                17
#  11020                 1
#  11021                 1

# %%
dfF = pd.DataFrame(Frequency)

percentiles = dfF['Sales Order'].quantile([0.25, 0.5, 0.75, 1])
dfF['Sales Order'] = dfF['Sales Order'].astype(int)

dfF['Frequency_Score'] = pd.cut(dfF['Sales Order'], bins=[-float('inf')] + list(percentiles) + [float('inf')], labels=[4, 3, 2, 1], include_lowest=True, duplicates='drop')
dfF.head(30)
# Out:
#              Sales Order Frequency_Score
# CustomerKey
# -1                  3796               2
#  11000                 3               2
#  11001                 3               2
#  11002                 3               2
#  11003                 3               2
#  11004                 3               2
#  11005                 3               2
#  11006                 3               2
#  11007                 3               2
#  11008                 3               2
#  11009                 3               2
#  11010                 3               2
#  11011                 3               2
#  11012                 2               3
#  11013                 2               3
#  11014                 2               3
#  11015                 1               4
#  11016                 1               4
#  11017                 3               2
#  11018                 3               2
#  11019                17               2
#  11020                 1               4
#  11021                 1               4
#  11022                 1               4
#  11023                 2               3
#  11024                 2               3
#  11025                 3               2
#  11026                 3               2
#  11027                 3               2
#  11028                 3               2

# %%
mean = dfF['Sales Order'].mean()
median = dfF['Sales Order'].median()
min_date = dfF['Sales Order'].min()
max_date = dfF['Sales Order'].max()
Q1 = dfF['Sales Order'].quantile(0.25)
Q2 = dfF['Sales Order'].quantile(0.5)
Q3 = dfF['Sales Order'].quantile(0.75)
IQR = Q3 - Q1
lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR
print('1 ', mean, '2 ', median, '3 ', min_date, '4 ', max_date, '5 ', Q1, '6 ', Q2, '7 ', Q3, '8 ', IQR, '9 ', lower_limit, '10 ', upper_limit)
# Out:
# 1  1.7016499864755208 2  1.0 3  1 4  3796 5  1.0 6  1.0 7  2.0 8  1.0 9  -0.5 10  3.5

# %%
Q1 = dfF['Sales Order'].quantile(0.25)
Q3 = dfF['Sales Order'].quantile(0.75)
IQR = Q3 - Q1
outliers = dfF[(dfF['Sales Order'] < (Q1 - 1.5 * IQR)) | (dfF['Sales Order'] > (Q3 + 1.5 * IQR))]
print(outliers)
# Out:
#              Sales Order Frequency_Score
# CustomerKey
# -1                  3796               2
#  11019                17               2
#  11078                17               2
#  11091                28               2
#  11131                 5               2
# ...                  ...             ...
#  15761                 4               2
#  15826                 4               2
#  16358                 4               2
#  16497                 4               2
#  16667                 4               2
#
# [246 rows x 2 columns]

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
dfF[["Sales Order"]].hist(bins=50, ax=axes[0])
sns.boxplot(x=dfF['Sales Order'])
# Out:
# <Axes: xlabel='Sales Order'>

# %%
clipped_total_rooms = BoxplotOutlierClipper().fit_transform(dfF["Sales Order"])

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
clipped_total_rooms.hist(bins=50, ax=axes[0])
clipped_total_rooms.to_frame().boxplot(ax=axes[1], vert=False);

# %%
# transform training data & save lambda value
# Add a constant to make all data positive
dfF['Sales Order'] = dfF['Sales Order'] + abs(dfF['Sales Order'].min()) + 1
fitted_data, fitted_lambda = stats.boxcox(dfF['Sales Order'])
 
# creating axes to draw plots
fig, ax = plt.subplots(1, 2)
 
# plotting the original data(non-normal) and 
# fitted data (normal)
sns.distplot(dfF['Sales Order'], hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2}, 
            label = "Non-Normal", color ="green", ax = ax[0])
 
sns.distplot(fitted_data, hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2}, 
            label = "Normal", color ="green", ax = ax[1])
 
# adding legends to the subplots
plt.legend(loc = "upper right")

#add title to each histogram
ax[0].set_title('Original Data')
ax[1].set_title('Box-Cox Transformed Data') 
 
# rescaling the subplots
fig.set_figheight(5)
fig.set_figwidth(10)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15972\3955406149.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfF['Sales Order'], hist = False, kde = True,
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15972\3955406149.py:15: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(fitted_data, hist = False, kde = True,
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)

# %%
#create log-transformed data
SalesOrder_log = np.log(dfF['Sales Order'])

#define grid of plots
fig, axs = plt.subplots(nrows=1, ncols=2)

# plotting the original data(non-normal) and 
# fitted data (normal)
sns.distplot(dfF['Sales Order'], hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2}, 
            label = "Non-Normal", color ="green", ax = axs[0])
 
sns.distplot(SalesOrder_log, hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2}, 
            label = "Normal", color ="green", ax = axs[1])
 
# adding legends to the subplots
plt.legend(loc = "upper right")

#add title to each histogram
axs[0].set_title('Original Data')
axs[1].set_title('Log-Transformed Data')
# rescaling the subplots
fig.set_figheight(5)
fig.set_figwidth(10)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15972\3812401280.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfF['Sales Order'], hist = False, kde = True,
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15972\3812401280.py:13: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(SalesOrder_log, hist = False, kde = True,
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)

# %%
# Create square root-transformed data
SalesOrder_sqrt = np.sqrt(dfF['Sales Order'])

# Define grid of plots
fig, axs = plt.subplots(nrows=1, ncols=2)

# Plotting the original data(non-normal) and fitted data (normal)
sns.distplot(dfF['Sales Order'], hist = False, kde = True,
             kde_kws = {'shade': True, 'linewidth': 2}, 
             label = "Non-Normal", color ="green", ax = axs[0])
 
sns.distplot(SalesOrder_sqrt, hist = False, kde = True,
             kde_kws = {'shade': True, 'linewidth': 2}, 
             label = "Normal", color ="green", ax = axs[1])
 
# Adding legends to the subplots
plt.legend(loc = "upper right")

# Add title to each histogram
axs[0].set_title('Original Data')
axs[1].set_title('Square Root-Transformed Data')
# rescaling the subplots
fig.set_figheight(5)
fig.set_figwidth(10)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15972\3134102773.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfF['Sales Order'], hist = False, kde = True,
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15972\3134102773.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(SalesOrder_sqrt, hist = False, kde = True,
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)

# %%
# Create cube root-transformed data
SalesOrder_cbrt = np.cbrt(dfF['Sales Order'])

# Define grid of plots
fig, axs = plt.subplots(nrows=1, ncols=2)

# Plotting the original data(non-normal) and fitted data (normal)
sns.distplot(dfF['Sales Order'], hist = False, kde = True,
             kde_kws = {'shade': True, 'linewidth': 2}, 
             label = "Non-Normal", color ="green", ax = axs[0])
 
sns.distplot(SalesOrder_cbrt, hist = False, kde = True,
             kde_kws = {'shade': True, 'linewidth': 2}, 
             label = "Normal", color ="green", ax = axs[1])
 
# Adding legends to the subplots
plt.legend(loc = "upper right")

# Add title to each histogram
axs[0].set_title('Original Data')
axs[1].set_title('Cube Root-Transformed Data')
# rescaling the subplots
fig.set_figheight(5)
fig.set_figwidth(10)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15972\2127125989.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfF['Sales Order'], hist = False, kde = True,
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15972\2127125989.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(SalesOrder_cbrt, hist = False, kde = True,
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)

# %% [markdown]
# **Calculate Monetary**
#
# Monentary of each CustomerKey is calculated by summing 'Sales Amount'.

# %%
Monetary = df.groupby(['CustomerKey']).agg({'Sales Amount': lambda x: x.sum()})
Monetary.head(15)
# Out:
#              Sales Amount
# CustomerKey
# -1            80450596.11
#  11000            8248.99
#  11001            6383.88
#  11002            8114.04
#  11003            8139.29
#  11004            8196.01
#  11005            8121.33
#  11006            8119.03
#  11007            8211.00
#  11008            8106.31
#  11009            8091.33
#  11010            8088.04
#  11011            8133.04
#  11012              81.26
#  11013             113.96

# %%
dfM = pd.DataFrame(Monetary)
dfM['Monetary_Score'] = pd.qcut(dfM['Sales Amount'], q=4, labels=[4, 3, 2, 1])
dfM.head(15)
# Out:
#              Sales Amount Monetary_Score
# CustomerKey
# -1            80450596.11              1
#  11000            8248.99              1
#  11001            6383.88              1
#  11002            8114.04              1
#  11003            8139.29              1
#  11004            8196.01              1
#  11005            8121.33              1
#  11006            8119.03              1
#  11007            8211.00              1
#  11008            8106.31              1
#  11009            8091.33              1
#  11010            8088.04              1
#  11011            8133.04              1
#  11012              81.26              3
#  11013             113.96              3

# %%
mean = dfM['Sales Amount'].mean()
median = dfM['Sales Amount'].median()
min_date = dfM['Sales Amount'].min()
max_date = dfM['Sales Amount'].max()
Q1 = dfM['Sales Amount'].quantile(0.25)
Q2 = dfM['Sales Amount'].quantile(0.5)
Q3 = dfM['Sales Amount'].quantile(0.75)
IQR = Q3 - Q1
lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR
print('1 ', mean, '2 ', median, '3 ', min_date, '4 ', max_date, '5 ', Q1, '6 ', Q2, '7 ', Q3, '8 ', IQR, '9 ', lower_limit, '10 ', upper_limit)
# Out:
# 1  5940.453015958886 2  271.45 3  2.29 4  80450596.11000001 5  49.97 6  271.45 7  2511.3199999999993 8  2461.3499999999995 9  -3642.0549999999994 10  6203.344999999998

# %%
Q1 = dfM['Sales Amount'].quantile(0.25)
Q3 = dfM['Sales Amount'].quantile(0.75)
IQR = Q3 - Q1
outliers = dfM[(dfM['Sales Amount'] < (Q1 - 1.5 * IQR)) | (dfM['Sales Amount'] > (Q3 + 1.5 * IQR))]
print(outliers)
# Out:
#              Sales Amount Monetary_Score
# CustomerKey
# -1            80450596.11              1
#  11000            8248.99              1
#  11001            6383.88              1
#  11002            8114.04              1
#  11003            8139.29              1
# ...                   ...            ...
#  18173            7189.35              1
#  18177            7043.56              1
#  19031            7226.38              1
#  19032            6938.58              1
#  19614            6217.21              1
#
# [678 rows x 2 columns]

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
dfM[["Sales Amount"]].hist(bins=50, ax=axes[0])
sns.boxplot(x=dfM['Sales Amount'])
# Out:
# <Axes: xlabel='Sales Amount'>

# %%
clipped_total_rooms = BoxplotOutlierClipper().fit_transform(dfM["Sales Amount"])

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
clipped_total_rooms.hist(bins=50, ax=axes[0])
clipped_total_rooms.to_frame().boxplot(ax=axes[1], vert=False);

# %%
# transform training data & save lambda value
# Add a constant to make all data positive
dfM['Sales Amount'] = dfM['Sales Amount'] + abs(dfM['Sales Amount'].min()) + 1
fitted_data, fitted_lambda = stats.boxcox(dfM['Sales Amount'])
 
# creating axes to draw plots
fig, ax = plt.subplots(1, 2)
 
# plotting the original data(non-normal) and 
# fitted data (normal)
sns.distplot(dfM['Sales Amount'], hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2}, 
            label = "Non-Normal", color ="green", ax = ax[0])
 
sns.distplot(fitted_data, hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2}, 
            label = "Normal", color ="green", ax = ax[1])
 
# adding legends to the subplots
plt.legend(loc = "upper right")

#add title to each histogram
ax[0].set_title('Original Data')
ax[1].set_title('Box-Cox Transformed Data') 
 
# rescaling the subplots
fig.set_figheight(5)
fig.set_figwidth(10)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15972\3261196372.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfM['Sales Amount'], hist = False, kde = True,
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15972\3261196372.py:15: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(fitted_data, hist = False, kde = True,
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)

# %%
#create log-transformed data
SalesAmount_log = np.log(dfM['Sales Amount'])

#define grid of plots
fig, axs = plt.subplots(nrows=1, ncols=2)

# plotting the original data(non-normal) and 
# fitted data (normal)
sns.distplot(dfM['Sales Amount'], hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2}, 
            label = "Non-Normal", color ="green", ax = axs[0])
 
sns.distplot(SalesAmount_log, hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2}, 
            label = "Normal", color ="green", ax = axs[1])
 
# adding legends to the subplots
plt.legend(loc = "upper right")

#add title to each histogram
axs[0].set_title('Original Data')
axs[1].set_title('Log-Transformed Data')
# rescaling the subplots
fig.set_figheight(5)
fig.set_figwidth(10)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15972\737460486.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfM['Sales Amount'], hist = False, kde = True,
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15972\737460486.py:13: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(SalesAmount_log, hist = False, kde = True,
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)

# %%
# Create square root-transformed data
SalesAmount_sqrt = np.sqrt(dfM['Sales Amount'])

# Define grid of plots
fig, axs = plt.subplots(nrows=1, ncols=2)

# Plotting the original data(non-normal) and fitted data (normal)
sns.distplot(dfM['Sales Amount'], hist = False, kde = True,
             kde_kws = {'shade': True, 'linewidth': 2}, 
             label = "Non-Normal", color ="green", ax = axs[0])
 
sns.distplot(SalesAmount_sqrt, hist = False, kde = True,
             kde_kws = {'shade': True, 'linewidth': 2}, 
             label = "Normal", color ="green", ax = axs[1])
 
# Adding legends to the subplots
plt.legend(loc = "upper right")

# Add title to each histogram
axs[0].set_title('Original Data')
axs[1].set_title('Square Root-Transformed Data')
# rescaling the subplots
fig.set_figheight(5)
fig.set_figwidth(10)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15972\2595912645.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfM['Sales Amount'], hist = False, kde = True,
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15972\2595912645.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(SalesAmount_sqrt, hist = False, kde = True,
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)

# %%
# Create square root-transformed data
SalesAmount_cbrt = np.cbrt(dfM['Sales Amount'])

# Define grid of plots
fig, axs = plt.subplots(nrows=1, ncols=2)

# Plotting the original data(non-normal) and fitted data (normal)
sns.distplot(dfM['Sales Amount'], hist = False, kde = True,
             kde_kws = {'shade': True, 'linewidth': 2}, 
             label = "Non-Normal", color ="green", ax = axs[0])
 
sns.distplot(SalesAmount_cbrt, hist = False, kde = True,
             kde_kws = {'shade': True, 'linewidth': 2}, 
             label = "Normal", color ="green", ax = axs[1])
 
# Adding legends to the subplots
plt.legend(loc = "upper right")

# Add title to each histogram
axs[0].set_title('Original Data')
axs[1].set_title('Cube Root-Transformed Data')
# rescaling the subplots
fig.set_figheight(5)
fig.set_figwidth(10)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15972\1781781442.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfM['Sales Amount'], hist = False, kde = True,
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15972\1781781442.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(SalesAmount_cbrt, hist = False, kde = True,
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)

# %%
RFM = pd.concat([dfR, dfF, dfM], axis=1)
dfR.columns = ['Recency', 'Recency_Score']
dfF.columns = ['Frequency', 'Frequency_Score']
dfM.columns = ['Monetary', 'Monetary_Score']
RFM['RFM_Score'] = RFM['Recency_Score'].astype(str) + RFM['Frequency_Score'].astype(str) + RFM['Monetary_Score'].astype(str)
RFM.head(10)
# Out:
#              Date Recency_Score  Sales Order Frequency_Score  Sales Amount  \
# CustomerKey
# -1              1             1         3798               2   80450599.40
#  11000        256             4            5               2       8252.28
#  11001         35             1            5               2       6387.17
#  11002        325             4            5               2       8117.33
#  11003        249             3            5               2       8142.58
#  11004        258             4            5               2       8199.30
#  11005        257             4            5               2       8124.62
#  11006        245             3            5               2       8122.32
#  11007        301             4            5               2       8214.29
#  11008        318             4            5               2       8109.60
#
#             Monetary_Score RFM_Score
# CustomerKey
# -1                       1       121
#  11000                   1       421
#  11001                   1       121
#  11002                   1       421
#  11003                   1       321
#  11004                   1       421
#  11005                   1       421
#  11006                   1       321
#  11007                   1       421
#  11008                   1       421
